# %% [markdown]
# ## Homework 1: Part 2
# ## Implementing regularized linear regression
# In this part, you will implement regularized linear regression and use it to
# study models with different bias-variance properties.
#
# This notebook contains code that helps you get started on
# linear regression with regularization.
# You will need to complete functions in
# **reg_linear_regressor.py** and **utils.py**.
# Modify this notebook in places marked by **TODO:**.

# %% [markdown]
# ## Regularized linear regression: an example
# In this problem, you will implement regularized linear regression
# to predict the amount of water flowing out of a dam using the change
# of water level in a reservoir. We will begin by visualizing the dataset containing historical records on the
# change in the water level $x$, and the amount of water $y$, flowing out of the dam.
# This dataset is divided into three parts:
# - A training set that you will use to learn the model:  X,  y.
# - A validation set for determining the regularization parameter: Xval, yval.
# - A test set for evaluating the performance of your model:  Xtest, ytest. These are unseen examples that were not used during the training of the model.
#
# Run the cell below and it  will plot the training data as shown in Figure 6 in your assignment handout.

# %%
import numpy as np
import matplotlib.pyplot as plt
import utils
import plot_utils
from reg_linear_regressor_multi import RegularizedLinearReg_SquaredLoss

# This is a bit of magic to make matplotlib figures appear inline in the notebook
# rather than in a new window.

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# Some more magic so that the notebook will reload external python modules;
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython

# %load_ext autoreload
# %autoreload 2

########################################################################
## =========== Part 1: Loading and Visualizing Data ===================#
########################################################################
# Load Training Data

print('Loading and Visualizing Data ...')

X, y, Xtest, ytest, Xval, yval = utils.load_mat('ex2data1.mat')

print(X.shape, y.shape)
print(Xtest.shape, ytest.shape)
print(Xval.shape, yval.shape)
# Plot training data

plot_utils.plot_data(X,y,'Change in water level (x)','Water flowing out of the dam (y)')
plt.show()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Loading and Visualizing Data ...
# (12,) (12,)
# (21,) (21,)
# (21,) (21,)

# %% [markdown]
# ## Regularized Linear Regression cost function and gradient (vectorized)
# You should now implement the loss function and gradient of the
# loss function for regularized linear regression in **reg_linear_regression_multi.py**. Then run the cell below.
# Regularized linear regression has the following cost function:
# $$J(\theta) = \frac{1}{2m} \left( \sum_{i=1}^{m} {( y^{(i)} - h_\theta(x^{(i)})}^2\right) + \frac{\lambda}{2m}\left( \sum_{j=1}^{n} {\theta_j}^2 \right) $$
# where $\lambda$ is a regularization parameter which controls the degree of regularization
# (thus, help preventing overfitting). The regularization term puts
# a penalty on the overall cost $J(\theta)$. As the magnitudes of the model parameters $\theta_j$ increase, the penalty increases as well. Note that you should not regularize the $\theta_0$ term. You should now complete the code for the method loss in the class Reg_LinearRegression_SquaredLoss in the file reg_linear_regressor_multi.py to calculate $J(\theta)$. Vectorize your code and avoid writing for loops.
#
# Correspondingly, the partial derivative of the regularized linear regression  cost function
# with respect to  $\theta_j$ is defined as:
# \begin{eqnarray*}
# \frac{\partial J(\theta)}{\partial \theta_0} & = & \frac{1}{m} \sum_{i=1}^{m} (h_\theta(x^{(i)}) - y^{(i)}){x_j}^{(i)} \\
# \frac{\partial J(\theta)}{\partial \theta_j} & = & \left(\frac{1}{m} \sum_{i=1}^{m} (h_\theta(x^{(i)}) - y^{(i)} ){x_j}^{(i)}\right) + \frac{\lambda}{m}{\theta_j} \; \; \; \mbox{ for }j \geq 1\\
# \end{eqnarray*}
# You should now complete the code for the method grad_loss in the class {Reg_LinearRegression_SquaredLoss in the file reg_linear_regressor_multi.py}
# to  calculate the gradient, returning
# it in the variable grad.
#
# Then evaluate the cell below. It runs the train method in  reg_linear_regressor_multi.py to compute the optimal value
# of $\theta$. This training function uses scipy's fmin_bfgs to optimize the cost function.
# Here we have set the regularization parameter $\lambda$ to zero.
#
# The best fit line plotted by the script  tells us that the model is
# not a good fit to the data because the data is non-linear. While
# visualizing the best fit as shown is one possible way to debug your learning
# algorithm, it is not always easy to visualize the data and model. In the next
# cell, you will implement a function to generate learning curves that can
# help you debug your learning algorithm even if it is not easy to visualize the
# data.

# %%
# append a column of ones to matrix X

XX = np.vstack([np.ones((X.shape[0],)),X]).T

#  Train linear regression with lambda = 0

reglinear_reg1 = RegularizedLinearReg_SquaredLoss()
theta_opt0 = reglinear_reg1.train(XX,y,reg=0.0,num_iters=1000)
print('Theta at lambda = 0 is %s' % (theta_opt0))

# plot fit over data and show it (or save it in fig7.pdf)
plot_utils.plot_data(X,y,'Change in water level (x)','Water flowing out of the dam (y)')
plt.plot(X,np.dot(XX,theta_opt0),'g-',linewidth=3)
plt.show()
# Out:
# Optimization terminated successfully.
#          Current function value: 22.373906
#          Iterations: 5
#          Function evaluations: 6
#          Gradient evaluations: 6
# Theta at lambda = 0 is [13.08790353  0.36777923]

# %% [markdown]
# ## Learning curve for linear regression
# An important concept in machine learning is the bias-variance tradeoff. Models
# with high bias are not complex enough for the data and tend to underfit,
# while models with high variance overfit  the training data.
# Here you will plot training and test errors on a
# learning curve to diagnose bias-variance problems.
#
# A  learning curve plots
# training and cross validation error as a function of training set size. You will complete the
# function  learning_curve in utils.py so that it returns a vector of errors for the
# training set and  validation set.
# To obtain different training set sizes,
# use different subsets of the original training set X. Specifically, for
# a training set size of $i$, you should use the first $i$ examples.
#
# You can use the train function to find the parameter $\theta$. Note
# that the regularization $\lambda$  is passed as a parameter to the learning_curve function.
# After learning the $\theta$ parameter, you should compute the error on the training
# and validation sets. Recall that the training error for a dataset is
# defined as:
# $$ J(\theta) = \frac{1}{2m} \left( \sum_{i=1}^{m} {( y^{(i)} - h_\theta(x^{(i)})}^2\right)  $$
#
#
# In particular, note that the training error does not include the regularization
# term. One way to compute the training error is to use your existing
# cost function and set the regularization parameter reg to 0 only when using it to compute the training error
# and validation error. When you are computing the training set error,
# make sure you compute it on the training subset
# instead of the entire training set. However, for the validation error,
# you should compute it over the entire validation set. You should store
# the computed errors in the vectors error_train and error_val.
# When you are finished, the cell below will print the learning curves and produce
# a plot similar to Figure 8 in the assignment handout.

# %%
reg = 1.0
XXval = np.vstack([np.ones((Xval.shape[0],)),Xval]).T

# implement the learning_curve function in utils.py
# this script will run your function and show the learning curve

error_train, error_val = utils.learning_curve(XX,y,XXval,yval,reg)
plot_utils.plot_learning_curve(error_train, error_val,reg)
plt.show()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 5
#          Function evaluations: 9
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 0.001307
#          Iterations: 10
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 3.335017
#          Iterations: 3
#          Function evaluations: 5
#          Gradient evaluations: 5
# Optimization terminated successfully.
#          Current function value: 2.881847
#          Iterations: 3
#          Function evaluations: 5
#          Gradient evaluations: 5
# Optimization terminated successfully.
#          Current function value: 13.174273
#          Iterations: 5
#          Function evaluations: 6
#          Gradient evaluations: 6
# Optimization terminated successfully.
#          Current function value: 19.461396
#          Iterations: 5
#          Function evaluations: 6
#          Gradient evaluations: 6
# Optimization terminated successfully.
#          Current function value: 20.112149
#          Iterations: 4
#          Function evaluations: 5
#          Gradient evaluations: 5
# Optimization terminated successfully.
#          Current function value: 18.184047
#          Iterations: 5
#          Function evaluations: 6
#          Gradient evaluations: 6
# Optimization terminated successfully.
#          Current function value: 22.618880
#          Iterations: 5
#          Function evaluations: 6
#          Gradient evaluations: 6
# Optimization terminated successfully.
#          Current function value: 23.268598
#          Iterations: 6
#          Function evaluations: 7
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 24.323253
#          Iterations: 5
#          Function evaluations: 6
#          Gradient evaluations: 6

# %% [markdown]
# ## Polynomial regression: expanding the basis functions
# The problem with our linear model was that it was too simple for the data
# and resulted in underfitting (high bias). In this problem, you will address this issue by adding more features. In particular, you will consider hypotheses of the form
# $$ h_\theta(x) = \theta_0 + \theta_1 x + \theta_2 x^2 + \ldots + \theta_p x^p $$
# This is still a linear model from the point of view of the parameter space. We have augmented the features with powers of $x$.
# Code in the cell below builds these features using sklearn's preprocessing module.
#
# We use a polynomial of degree 6.
# It turns out that if we run the training directly on the projected data,  it will
# not work well as the features would be badly scaled (e.g., an example with
# $x = 40$ will now have a feature $x^6 = 40^6 = 4.1 \times 10^{9}$). Therefore, you will
# need to use feature normalization.
# Before learning the parameter $\theta$ for the polynomial regression, the script in the cell below will
# first call the **feature_normalize** function you wrote earlier. It will normalize the features of the training set,
# storing the mu, sigma parameters separately. It will project the validation and test sets too, but normalize them using the same mu and sigma parameters.

# %% [markdown]
# - poly.fit_transform(X) <- X has to be array shape, so need to reshape!

# %%
from utils import feature_normalize
import sklearn
from sklearn.preprocessing import PolynomialFeatures

# Map X onto polynomial features and normalize
# We will consider a 6th order polynomial fit for the data
p = 6
poly = sklearn.preprocessing.PolynomialFeatures(degree=p,include_bias=False)  # Need to set include_bias=False, or it'll pad 1 in the front
X_poly = poly.fit_transform(np.reshape(X,(len(X),1)))    # shape (12,6)
X_poly, mu, sigma = utils.feature_normalize(X_poly)

# add a column of ones to X_poly (after normalization!)

XX_poly = np.vstack([np.ones((X_poly.shape[0],)),X_poly.T]).T

# map Xtest and Xval into the same polynomial features

X_poly_test = poly.fit_transform(np.reshape(Xtest,(len(Xtest),1)))
X_poly_val = poly.fit_transform(np.reshape(Xval,(len(Xval),1)))

# normalize these two sets with the same mu and sigma

X_poly_test = (X_poly_test - mu) / sigma
X_poly_val = (X_poly_val - mu) / sigma

# add a column of ones to both X_poly_test and X_poly_val
XX_poly_test = np.vstack([np.ones((X_poly_test.shape[0],)),X_poly_test.T]).T
XX_poly_val = np.vstack([np.ones((X_poly_val.shape[0],)),X_poly_val.T]).T

# %% [markdown]
# ## Learning curves for polynomial regression
# The cell below trains a linear model on the transformed data. After learning $\theta$, you should see two plots
# generated for polynomial regression with $\lambda= 0$.

# %%
reg_choice = [0, 1, 10, 100]
for reg in reg_choice:
    reglinear_reg2 = RegularizedLinearReg_SquaredLoss()
    theta_opt1 = reglinear_reg2.train(XX_poly,y,reg=reg,num_iters=10000)
    # print('Theta at lambda = 0 is %s' % (theta_opt1))
    print(f"theta at lambda = {reg} is {theta_opt1}")

    # plot data and training fit for the 6th order polynomial 
    plt_title_txt = 'Polynomial Regression fit with lambda = ' + str(reg) +'and polynomial features of degree = ' + str(p)
    plot_utils.plot_fit(X, y, np.min(X), np.max(X), mu,sigma, theta_opt1, p,'Change in water level (x)','Water flowing out of dam (y)', plt_title_txt)
    plt.show()

    # plot learning curve for data (6th order polynomail basis function) 

    error_train,error_val = utils.learning_curve(XX_poly,y,XX_poly_val,yval,reg)
    plot_utils.plot_learning_curve(error_train,error_val,reg)
    plt.show()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.198053
#          Iterations: 33
#          Function evaluations: 36
#          Gradient evaluations: 36
# theta at lambda = 0 is [11.2175893  -1.92981718 14.47430101 -2.8597999  -3.26170344  3.78582346
#  -3.04808148]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 2
#          Function evaluations: 3
#          Gradient evaluations: 3
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 5
#          Function evaluations: 6
#          Gradient evaluations: 6
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 10
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 19
#          Function evaluations: 21
#          Gradient evaluations: 21
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 23
#          Function evaluations: 24
#          Gradient evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 32
#          Function evaluations: 33
#          Gradient evaluations: 33
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 41
#          Function evaluations: 42
#          Gradient evaluations: 42
# Optimization terminated successfully.
#          Current function value: 0.075859
#          Iterations: 39
#          Function evaluations: 41
#          Gradient evaluations: 41
# Optimization terminated successfully.
#          Current function value: 0.183744
#          Iterations: 36
#          Function evaluations: 38
#          Gradient evaluations: 38
# Optimization terminated successfully.
#          Current function value: 0.224868
#          Iterations: 36
#          Function evaluations: 37
#          Gradient evaluations: 37
# Optimization terminated successfully.
#          Current function value: 0.204675
#          Iterations: 36
#          Function evaluations: 38
#          Gradient evaluations: 38
# Optimization terminated successfully.
#          Current function value: 2.903375
#          Iterations: 16
#          Function evaluations: 18
#          Gradient evaluations: 18
# theta at lambda = 1 is [11.2175893  -2.07210649  5.09764038  0.10269411  2.4097854  -1.06356841
#   0.22165962]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 10
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 0.018273
#          Iterations: 12
#          Function evaluations: 13
#          Gradient evaluations: 13
# Optimization terminated successfully.
#          Current function value: 2.864021
#          Iterations: 16
#          Function evaluations: 17
#          Gradient evaluations: 17
# Optimization terminated successfully.
#          Current function value: 2.286911
#          Iterations: 20
#          Function evaluations: 22
#          Gradient evaluations: 22
# Optimization terminated successfully.
#          Current function value: 1.840084
#          Iterations: 17
#          Function evaluations: 19
#          Gradient evaluations: 19
# Optimization terminated successfully.
#          Current function value: 2.449303
#          Iterations: 18
#          Function evaluations: 19
#          Gradient evaluations: 19
# Optimization terminated successfully.
#          Current function value: 2.100542
#          Iterations: 16
#          Function evaluations: 17
#          Gradient evaluations: 17
# Optimization terminated successfully.
#          Current function value: 2.250769
#          Iterations: 16
#          Function evaluations: 18
#          Gradient evaluations: 18
# Optimization terminated successfully.
#          Current function value: 2.772643
#          Iterations: 17
#          Function evaluations: 19
#          Gradient evaluations: 19
# Optimization terminated successfully.
#          Current function value: 2.578659
#          Iterations: 16
#          Function evaluations: 17
#          Gradient evaluations: 17
# Optimization terminated successfully.
#          Current function value: 2.412973
#          Iterations: 16
#          Function evaluations: 18
#          Gradient evaluations: 18
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 55.155352
#          Iterations: 6
#          Function evaluations: 58
#          Gradient evaluations: 46
# theta at lambda = 10 is [11.19142053 -1.90805644  1.9074381  -0.54324364  1.68349536 -0.18936319
#   1.27408486]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 8
#          Function evaluations: 13
#          Gradient evaluations: 13
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.274038
#          Iterations: 7
#          Function evaluations: 73
#          Gradient evaluations: 61
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 70.491336
#          Iterations: 7
#          Function evaluations: 54
#          Gradient evaluations: 44
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 76.959006
#          Iterations: 11
#          Function evaluations: 61
#          Gradient evaluations: 49
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 79.067314
#          Iterations: 8
#          Function evaluations: 54
#          Gradient evaluations: 42
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 70.520093
#          Iterations: 6
#          Function evaluations: 81
#          Gradient evaluations: 69
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 66.334355
#          Iterations: 7
#          Function evaluations: 72
#          Gradient evaluations: 60
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 60.775377
#          Iterations: 6
#          Function evaluations: 48
#          Gradient evaluations: 36
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 64.098480
#          Iterations: 6
#          Function evaluations: 60
#          Gradient evaluations: 48
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 56.051455
#          Iterations: 6
#          Function evaluations: 64
#          Gradient evaluations: 52
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 61.966991
#          Iterations: 6
#          Function evaluations: 73
#          Gradient evaluations: 61
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 235.505392
#          Iterations: 4
#          Function evaluations: 83
#          Gradient evaluations: 71
# theta at lambda = 100 is [ 8.30855715 -0.38731861  0.328316   -0.28296705  0.09612467 -0.30764175
#  -0.04478826]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 9
#          Function evaluations: 42
#          Gradient evaluations: 42
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.641886
#          Iterations: 6
#          Function evaluations: 78
#          Gradient evaluations: 66
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 331.479192
#          Iterations: 4
#          Function evaluations: 82
#          Gradient evaluations: 70
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 826.341634
#          Iterations: 4
#          Function evaluations: 101
#          Gradient evaluations: 89
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 324.165781
#          Iterations: 4
#          Function evaluations: 84
#          Gradient evaluations: 72
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 248.938653
#          Iterations: 4
#          Function evaluations: 77
#          Gradient evaluations: 66
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 394.987568
#          Iterations: 6
#          Function evaluations: 124
#          Gradient evaluations: 112
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 338.386250
#          Iterations: 5
#          Function evaluations: 98
#          Gradient evaluations: 86
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 472.204460
#          Iterations: 5
#          Function evaluations: 67
#          Gradient evaluations: 55
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 255.147191
#          Iterations: 4
#          Function evaluations: 88
#          Gradient evaluations: 76
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 269.276704
#          Iterations: 4
#          Function evaluations: 78
#          Gradient evaluations: 66

# %% [markdown]
# ## Adjusting the regularization parameter
# You will now explore how the regularization parameter
# affects the bias-variance of regularized polynomial regression. You should
# now modify the  lambda parameter in the cell above and try $\lambda = 1, 10, 100$. For
# each of these values, the script will generate a polynomial fit to the data
# and also a learning curve. Submit two plots for each value of lambda: the fit as well as the learning curve. Comment on the impact of the choice of lambda on the quality of the learned model in your **writeup.pdf**.

# %% [markdown]
# ## Calculating test error on the best model
# To get a better indication of a model's performance in the real
# world, it is important to evaluate the final model on a test set that was
# not used in any part of training (that is, it was neither used to select the regularization parameter, nor to learn the model parameters).
# Calculate the error of the best model that you found with the previous analysis
# and report it.

# %%
# TODO: your code for computing test error on the best model (model with the best lambda)
reglinear_reg4 = RegularizedLinearReg_SquaredLoss()
theta_opt4 = reglinear_reg4.train(XX_poly,y,reg=1,num_iters=10000)
err = reglinear_reg4.loss(theta_opt4, XX_poly_test, ytest, 0)
print(f"Error of the best model currently found with lambda = 0.1: {err}")
# Out:
# Optimization terminated successfully.
#          Current function value: 2.903375
#          Iterations: 16
#          Function evaluations: 18
#          Gradient evaluations: 18
# Error of the best model currently found with lambda = 0.1: 4.003525438569828

# %% [markdown]
# ## Selecting $\lambda$ using a validation set
# You will implement an automated method to select the $\lambda$ parameter. Concretely, you will use a validation set to evaluate how good each $\lambda$ value is. After selecting the best $\lambda$ value using the
# validation set, we can then evaluate the model on the test set to estimate
# how well the model will perform on actual unseen data.
# **Complete the function validation_curve.m in utils.py**. Specifically,
# you should should use the train method on an instance of the class Reg_Linear_Regressor to train the model using
# different values of $\lambda$ and to compute the training error and  validation error.
# You should try $\lambda$ in the following range: \{0, 0.001, 0.003, 0.01, 0.03, 0.1, 0.3, 1, 3, 10\}.
#
# After you have completed the code, run the cell below to plot a validation curve of $\lambda$ versus the error. This plot  allows you select
# which $\lambda$ value to use. Due to randomness
# in the training and validation splits of the dataset, the cross validation error
# can sometimes be lower than the training error. Submit a pdf version of this plot in **writeup.pdf**. Comment on the best choice of $\lambda$ for this problem.

# %%
# now implement the validation_curve function in utils.py
# this function helps in determining the best lambda using a
# a validation set
# The code will now run your function and plot the figure 

reg_vec, error_train, error_val = utils.validation_curve(XX_poly,y,XX_poly_val,yval)
plot_utils.plot_lambda_selection(reg_vec,error_train,error_val)
plt.show()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.198053
#          Iterations: 33
#          Function evaluations: 36
#          Gradient evaluations: 36
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.200355
#          Iterations: 18
#          Function evaluations: 72
#          Gradient evaluations: 60
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.200850
#          Iterations: 18
#          Function evaluations: 77
#          Gradient evaluations: 65
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.205400
#          Iterations: 17
#          Function evaluations: 72
#          Gradient evaluations: 60
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.242581
#          Iterations: 16
#          Function evaluations: 62
#          Gradient evaluations: 50
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.433768
#          Iterations: 15
#          Function evaluations: 70
#          Gradient evaluations: 58
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.942155
#          Iterations: 14
#          Function evaluations: 71
#          Gradient evaluations: 59
# Optimization terminated successfully.
#          Current function value: 2.903375
#          Iterations: 16
#          Function evaluations: 18
#          Gradient evaluations: 18
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 10.175567
#          Iterations: 4
#          Function evaluations: 62
#          Gradient evaluations: 50
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 55.155352
#          Iterations: 6
#          Function evaluations: 58
#          Gradient evaluations: 46

# %% [markdown]
# ## Plotting learning curves with randomly selected examples
# In practice, especially for small training sets, when you plot learning curves
# to debug your algorithms, it is often helpful to average across multiple sets
# of randomly selected examples to determine the training error and
# validation error.
# Concretely, to determine the training error and cross validation error for
# $i$ examples, you should first randomly select $i$ examples from the training set
# and $i$ examples from the  validation set. You will then learn the model parameters using the randomly chosen training set and evaluate the parameters on the randomly chosen training set and validation set. The above
# steps should then be repeated multiple times (say 50) and the averaged error
# should be used to determine the training error and cross validation error for
# $i$ examples.
# Implement the above
# strategy for computing the learning curves. Complete the  function
# **learning_curve_averaged** in  **utils.py** to generate compute and generate this plot. Then evaluate the cell below.

# %%
# now implement the averaged learning curve function in utils.py
# The script runs your function, plots the curves and saves it in fig11.pdf

reg = 1.0
error_train,error_val = utils.averaged_learning_curve(XX_poly,y,XX_poly_val,yval,reg)
plot_utils.plot_learning_curve(error_train,error_val,reg)
plt.show()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 10
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 7
#          Function evaluations: 8
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 7
#          Function evaluations: 8
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 10
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 8
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 10
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 7
#          Function evaluations: 9
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 8
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 10
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 8
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 10
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 4
#          Function evaluations: 8
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 6
#          Function evaluations: 7
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 7
#          Function evaluations: 9
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 11
#          Function evaluations: 12
#          Gradient evaluations: 12
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 8
#          Function evaluations: 10
#          Gradient evaluations: 10
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 6
#          Function evaluations: 7
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 7
#          Function evaluations: 9
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 7
#          Function evaluations: 8
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 10
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 5
#          Function evaluations: 8
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 10
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 8
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 8
#          Function evaluations: 10
#          Gradient evaluations: 10
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 6
#          Function evaluations: 7
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 8
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 8
#          Function evaluations: 10
#          Gradient evaluations: 10
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 7
#          Function evaluations: 9
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 7
#          Function evaluations: 9
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 11
#          Function evaluations: 12
#          Gradient evaluations: 12
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 7
#          Function evaluations: 8
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 10
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 6
#          Function evaluations: 7
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 11
#          Function evaluations: 12
#          Gradient evaluations: 12
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 11
#          Function evaluations: 12
#          Gradient evaluations: 12
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 8
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 7
#          Function evaluations: 8
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 10
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 4
#          Function evaluations: 8
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 11
#          Function evaluations: 12
#          Gradient evaluations: 12
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 10
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 4
#          Function evaluations: 8
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 8
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 8
#          Function evaluations: 10
#          Gradient evaluations: 10
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 8
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 7
#          Function evaluations: 9
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 8
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 8
#          Function evaluations: 10
#          Gradient evaluations: 10
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 10
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 8
#          Function evaluations: 10
#          Gradient evaluations: 10
# Optimization terminated successfully.
#          Current function value: 0.540718
#          Iterations: 13
#          Function evaluations: 14
#          Gradient evaluations: 14
# Optimization terminated successfully.
#          Current function value: 4.309725
#          Iterations: 13
#          Function evaluations: 14
#          Gradient evaluations: 14
# Optimization terminated successfully.
#          Current function value: 3.118784
#          Iterations: 12
#          Function evaluations: 13
#          Gradient evaluations: 13
# Optimization terminated successfully.
#          Current function value: 0.077978
#          Iterations: 14
#          Function evaluations: 15
#          Gradient evaluations: 15
# Optimization terminated successfully.
#          Current function value: 0.001370
#          Iterations: 12
#          Function evaluations: 14
#          Gradient evaluations: 14
# Optimization terminated successfully.
#          Current function value: 1.970462
#          Iterations: 13
#          Function evaluations: 15
#          Gradient evaluations: 15
# Optimization terminated successfully.
#          Current function value: 0.077978
#          Iterations: 14
#          Function evaluations: 15
#          Gradient evaluations: 15
# Optimization terminated successfully.
#          Current function value: 0.004193
#          Iterations: 13
#          Function evaluations: 14
#          Gradient evaluations: 14
# Optimization terminated successfully.
#          Current function value: 2.094145
#          Iterations: 13
#          Function evaluations: 15
#          Gradient evaluations: 15
# Optimization terminated successfully.
#          Current function value: 0.001919
#          Iterations: 13
#          Function evaluations: 15
#          Gradient evaluations: 15
# Optimization terminated successfully.
#          Current function value: 0.018055
#          Iterations: 12
#          Function evaluations: 13
#          Gradient evaluations: 13
# Optimization terminated successfully.
#          Current function value: 4.309725
#          Iterations: 13
#          Function evaluations: 14
#          Gradient evaluations: 14
# Optimization terminated successfully.
#          Current function value: 0.435510
#          Iterations: 13
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 16
#          Function evaluations: 17
#          Gradient evaluations: 17
# Optimization terminated successfully.
#          Current function value: 0.435510
#          Iterations: 13
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 1.007982
#          Iterations: 12
#          Function evaluations: 13
#          Gradient evaluations: 13
# Optimization terminated successfully.
#          Current function value: 2.523330
#          Iterations: 11
#          Function evaluations: 14
#          Gradient evaluations: 14
# Optimization terminated successfully.
#          Current function value: 3.118784
#          Iterations: 12
#          Function evaluations: 13
#          Gradient evaluations: 13
# Optimization terminated successfully.
#          Current function value: 0.540169
#          Iterations: 14
#          Function evaluations: 15
#          Gradient evaluations: 15
# Optimization terminated successfully.
#          Current function value: 0.663830
#          Iterations: 12
#          Function evaluations: 13
#          Gradient evaluations: 13
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 10
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 0.000081
#          Iterations: 15
#          Function evaluations: 18
#          Gradient evaluations: 18
# Optimization terminated successfully.
#          Current function value: 0.000081
#          Iterations: 15
#          Function evaluations: 18
#          Gradient evaluations: 18
# Optimization terminated successfully.
#          Current function value: 0.240719
#          Iterations: 13
#          Function evaluations: 15
#          Gradient evaluations: 15
# Optimization terminated successfully.
#          Current function value: 2.498930
#          Iterations: 14
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 0.613052
#          Iterations: 18
#          Function evaluations: 19
#          Gradient evaluations: 19
# Optimization terminated successfully.
#          Current function value: 0.000452
#          Iterations: 13
#          Function evaluations: 15
#          Gradient evaluations: 15
# Optimization terminated successfully.
#          Current function value: 0.001370
#          Iterations: 12
#          Function evaluations: 14
#          Gradient evaluations: 14
# Optimization terminated successfully.
#          Current function value: 0.004053
#          Iterations: 12
#          Function evaluations: 15
#          Gradient evaluations: 15
# Optimization terminated successfully.
#          Current function value: 0.004053
#          Iterations: 12
#          Function evaluations: 15
#          Gradient evaluations: 15
# Optimization terminated successfully.
#          Current function value: 1.062285
#          Iterations: 11
#          Function evaluations: 12
#          Gradient evaluations: 12
# Optimization terminated successfully.
#          Current function value: 2.588469
#          Iterations: 15
#          Function evaluations: 17
#          Gradient evaluations: 17
# Optimization terminated successfully.
#          Current function value: 0.021077
#          Iterations: 16
#          Function evaluations: 18
#          Gradient evaluations: 18
# Optimization terminated successfully.
#          Current function value: 1.007982
#          Iterations: 12
#          Function evaluations: 13
#          Gradient evaluations: 13
# Optimization terminated successfully.
#          Current function value: 0.312008
#          Iterations: 12
#          Function evaluations: 13
#          Gradient evaluations: 13
# Optimization terminated successfully.
#          Current function value: 0.018106
#          Iterations: 12
#          Function evaluations: 13
#          Gradient evaluations: 13
# Optimization terminated successfully.
#          Current function value: 0.097571
#          Iterations: 12
#          Function evaluations: 14
#          Gradient evaluations: 14
# Optimization terminated successfully.
#          Current function value: 0.613052
#          Iterations: 18
#          Function evaluations: 19
#          Gradient evaluations: 19
# Optimization terminated successfully.
#          Current function value: 1.970462
#          Iterations: 13
#          Function evaluations: 15
#          Gradient evaluations: 15
# Optimization terminated successfully.
#          Current function value: 0.639641
#          Iterations: 14
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 0.046720
#          Iterations: 13
#          Function evaluations: 14
#          Gradient evaluations: 14
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 17
#          Function evaluations: 18
#          Gradient evaluations: 18
# Optimization terminated successfully.
#          Current function value: 2.094145
#          Iterations: 13
#          Function evaluations: 15
#          Gradient evaluations: 15
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 10
#          Function evaluations: 13
#          Gradient evaluations: 13
# Optimization terminated successfully.
#          Current function value: 3.259428
#          Iterations: 14
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 0.000452
#          Iterations: 13
#          Function evaluations: 15
#          Gradient evaluations: 15
# Optimization terminated successfully.
#          Current function value: 1.007982
#          Iterations: 12
#          Function evaluations: 13
#          Gradient evaluations: 13
# Optimization terminated successfully.
#          Current function value: 2.498930
#          Iterations: 14
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 0.018106
#          Iterations: 12
#          Function evaluations: 13
#          Gradient evaluations: 13
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 13
#          Function evaluations: 14
#          Gradient evaluations: 14
# Optimization terminated successfully.
#          Current function value: 0.120366
#          Iterations: 13
#          Function evaluations: 14
#          Gradient evaluations: 14
# Optimization terminated successfully.
#          Current function value: 2.135209
#          Iterations: 15
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 0.005748
#          Iterations: 12
#          Function evaluations: 14
#          Gradient evaluations: 14
# Optimization terminated successfully.
#          Current function value: 0.780964
#          Iterations: 15
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 2.135453
#          Iterations: 11
#          Function evaluations: 13
#          Gradient evaluations: 13
# Optimization terminated successfully.
#          Current function value: 0.020984
#          Iterations: 14
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 0.113038
#          Iterations: 14
#          Function evaluations: 15
#          Gradient evaluations: 15
# Optimization terminated successfully.
#          Current function value: 1.941189
#          Iterations: 17
#          Function evaluations: 19
#          Gradient evaluations: 19
# Optimization terminated successfully.
#          Current function value: 0.056207
#          Iterations: 15
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 0.560191
#          Iterations: 14
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 5.336139
#          Iterations: 14
#          Function evaluations: 15
#          Gradient evaluations: 15
# Optimization terminated successfully.
#          Current function value: 0.007492
#          Iterations: 18
#          Function evaluations: 19
#          Gradient evaluations: 19
# Optimization terminated successfully.
#          Current function value: 0.000924
#          Iterations: 11
#          Function evaluations: 13
#          Gradient evaluations: 13
# Optimization terminated successfully.
#          Current function value: 0.022137
#          Iterations: 15
#          Function evaluations: 17
#          Gradient evaluations: 17
# Optimization terminated successfully.
#          Current function value: 2.984284
#          Iterations: 15
#          Function evaluations: 18
#          Gradient evaluations: 18
# Optimization terminated successfully.
#          Current function value: 2.707076
#          Iterations: 13
#          Function evaluations: 14
#          Gradient evaluations: 14
# Optimization terminated successfully.
#          Current function value: 0.954279
#          Iterations: 14
#          Function evaluations: 15
#          Gradient evaluations: 15
# Optimization terminated successfully.
#          Current function value: 4.206992
#          Iterations: 14
#          Function evaluations: 15
#          Gradient evaluations: 15
# Optimization terminated successfully.
#          Current function value: 1.096011
#          Iterations: 13
#          Function evaluations: 15
#          Gradient evaluations: 15
# Optimization terminated successfully.
#          Current function value: 2.850788
#          Iterations: 15
#          Function evaluations: 17
#          Gradient evaluations: 17
# Optimization terminated successfully.
#          Current function value: 0.050830
#          Iterations: 14
#          Function evaluations: 15
#          Gradient evaluations: 15
# Optimization terminated successfully.
#          Current function value: 0.934401
#          Iterations: 14
#          Function evaluations: 15
#          Gradient evaluations: 15
# Optimization terminated successfully.
#          Current function value: 0.002107
#          Iterations: 15
#          Function evaluations: 17
#          Gradient evaluations: 17
# Optimization terminated successfully.
#          Current function value: 1.273903
#          Iterations: 14
#          Function evaluations: 15
#          Gradient evaluations: 15
# Optimization terminated successfully.
#          Current function value: 2.763476
#          Iterations: 14
#          Function evaluations: 15
#          Gradient evaluations: 15
# Optimization terminated successfully.
#          Current function value: 1.402556
#          Iterations: 14
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 0.731576
#          Iterations: 13
#          Function evaluations: 15
#          Gradient evaluations: 15
# Optimization terminated successfully.
#          Current function value: 0.709477
#          Iterations: 15
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 0.966173
#          Iterations: 12
#          Function evaluations: 14
#          Gradient evaluations: 14
# Optimization terminated successfully.
#          Current function value: 0.003054
#          Iterations: 13
#          Function evaluations: 15
#          Gradient evaluations: 15
# Optimization terminated successfully.
#          Current function value: 2.222055
#          Iterations: 15
#          Function evaluations: 17
#          Gradient evaluations: 17
# Optimization terminated successfully.
#          Current function value: 4.206992
#          Iterations: 14
#          Function evaluations: 15
#          Gradient evaluations: 15
# Optimization terminated successfully.
#          Current function value: 0.950667
#          Iterations: 14
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 3.832247
#          Iterations: 14
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 0.000008
#          Iterations: 14
#          Function evaluations: 15
#          Gradient evaluations: 15
# Optimization terminated successfully.
#          Current function value: 3.914865
#          Iterations: 16
#          Function evaluations: 18
#          Gradient evaluations: 18
# Optimization terminated successfully.
#          Current function value: 0.373003
#          Iterations: 14
#          Function evaluations: 15
#          Gradient evaluations: 15
# Optimization terminated successfully.
#          Current function value: 2.252975
#          Iterations: 15
#          Function evaluations: 17
#          Gradient evaluations: 17
# Optimization terminated successfully.
#          Current function value: 2.787235
#          Iterations: 14
#          Function evaluations: 15
#          Gradient evaluations: 15
# Optimization terminated successfully.
#          Current function value: 1.994247
#          Iterations: 15
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 0.012142
#          Iterations: 12
#          Function evaluations: 13
#          Gradient evaluations: 13
# Optimization terminated successfully.
#          Current function value: 2.337005
#          Iterations: 13
#          Function evaluations: 14
#          Gradient evaluations: 14
# Optimization terminated successfully.
#          Current function value: 0.015579
#          Iterations: 14
#          Function evaluations: 17
#          Gradient evaluations: 17
# Optimization terminated successfully.
#          Current function value: 3.431603
#          Iterations: 11
#          Function evaluations: 12
#          Gradient evaluations: 12
# Optimization terminated successfully.
#          Current function value: 1.431791
#          Iterations: 14
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 1.389245
#          Iterations: 14
#          Function evaluations: 15
#          Gradient evaluations: 15
# Optimization terminated successfully.
#          Current function value: 3.914865
#          Iterations: 16
#          Function evaluations: 18
#          Gradient evaluations: 18
# Optimization terminated successfully.
#          Current function value: 3.383195
#          Iterations: 12
#          Function evaluations: 13
#          Gradient evaluations: 13
# Optimization terminated successfully.
#          Current function value: 0.950667
#          Iterations: 14
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 1.721709
#          Iterations: 17
#          Function evaluations: 18
#          Gradient evaluations: 18
# Optimization terminated successfully.
#          Current function value: 0.078546
#          Iterations: 22
#          Function evaluations: 24
#          Gradient evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.071143
#          Iterations: 15
#          Function evaluations: 17
#          Gradient evaluations: 17
# Optimization terminated successfully.
#          Current function value: 2.462260
#          Iterations: 16
#          Function evaluations: 18
#          Gradient evaluations: 18
# Optimization terminated successfully.
#          Current function value: 1.137700
#          Iterations: 13
#          Function evaluations: 15
#          Gradient evaluations: 15
# Optimization terminated successfully.
#          Current function value: 0.155874
#          Iterations: 15
#          Function evaluations: 17
#          Gradient evaluations: 17
# Optimization terminated successfully.
#          Current function value: 3.349505
#          Iterations: 15
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 1.761323
#          Iterations: 13
#          Function evaluations: 14
#          Gradient evaluations: 14
# Optimization terminated successfully.
#          Current function value: 1.296303
#          Iterations: 13
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 2.266149
#          Iterations: 14
#          Function evaluations: 15
#          Gradient evaluations: 15
# Optimization terminated successfully.
#          Current function value: 3.512272
#          Iterations: 15
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 0.862754
#          Iterations: 16
#          Function evaluations: 17
#          Gradient evaluations: 17
# Optimization terminated successfully.
#          Current function value: 3.273881
#          Iterations: 12
#          Function evaluations: 14
#          Gradient evaluations: 14
# Optimization terminated successfully.
#          Current function value: 0.730098
#          Iterations: 13
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 3.675895
#          Iterations: 19
#          Function evaluations: 21
#          Gradient evaluations: 21
# Optimization terminated successfully.
#          Current function value: 2.145732
#          Iterations: 16
#          Function evaluations: 17
#          Gradient evaluations: 17
# Optimization terminated successfully.
#          Current function value: 6.065453
#          Iterations: 16
#          Function evaluations: 17
#          Gradient evaluations: 17
# Optimization terminated successfully.
#          Current function value: 1.103055
#          Iterations: 20
#          Function evaluations: 21
#          Gradient evaluations: 21
# Optimization terminated successfully.
#          Current function value: 0.655524
#          Iterations: 14
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 0.988056
#          Iterations: 13
#          Function evaluations: 15
#          Gradient evaluations: 15
# Optimization terminated successfully.
#          Current function value: 1.700055
#          Iterations: 17
#          Function evaluations: 19
#          Gradient evaluations: 19
# Optimization terminated successfully.
#          Current function value: 3.359606
#          Iterations: 12
#          Function evaluations: 13
#          Gradient evaluations: 13
# Optimization terminated successfully.
#          Current function value: 2.980281
#          Iterations: 17
#          Function evaluations: 19
#          Gradient evaluations: 19
# Optimization terminated successfully.
#          Current function value: 3.563863
#          Iterations: 16
#          Function evaluations: 18
#          Gradient evaluations: 18
# Optimization terminated successfully.
#          Current function value: 1.159582
#          Iterations: 17
#          Function evaluations: 19
#          Gradient evaluations: 19
# Optimization terminated successfully.
#          Current function value: 2.289418
#          Iterations: 16
#          Function evaluations: 17
#          Gradient evaluations: 17
# Optimization terminated successfully.
#          Current function value: 0.232289
#          Iterations: 18
#          Function evaluations: 19
#          Gradient evaluations: 19
# Optimization terminated successfully.
#          Current function value: 3.924775
#          Iterations: 14
#          Function evaluations: 15
#          Gradient evaluations: 15
# Optimization terminated successfully.
#          Current function value: 4.148255
#          Iterations: 16
#          Function evaluations: 17
#          Gradient evaluations: 17
# Optimization terminated successfully.
#          Current function value: 0.141972
#          Iterations: 14
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 1.642830
#          Iterations: 14
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 1.844838
#          Iterations: 15
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 1.053457
#          Iterations: 15
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 0.001587
#          Iterations: 15
#          Function evaluations: 17
#          Gradient evaluations: 17
# Optimization terminated successfully.
#          Current function value: 5.193446
#          Iterations: 18
#          Function evaluations: 19
#          Gradient evaluations: 19
# Optimization terminated successfully.
#          Current function value: 0.068196
#          Iterations: 18
#          Function evaluations: 21
#          Gradient evaluations: 21
# Optimization terminated successfully.
#          Current function value: 0.106392
#          Iterations: 16
#          Function evaluations: 17
#          Gradient evaluations: 17
# Optimization terminated successfully.
#          Current function value: 2.759113
#          Iterations: 16
#          Function evaluations: 17
#          Gradient evaluations: 17
# Optimization terminated successfully.
#          Current function value: 3.258661
#          Iterations: 17
#          Function evaluations: 18
#          Gradient evaluations: 18
# Optimization terminated successfully.
#          Current function value: 0.144833
#          Iterations: 20
#          Function evaluations: 22
#          Gradient evaluations: 22
# Optimization terminated successfully.
#          Current function value: 1.447174
#          Iterations: 19
#          Function evaluations: 21
#          Gradient evaluations: 21
# Optimization terminated successfully.
#          Current function value: 1.687624
#          Iterations: 14
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 3.682677
#          Iterations: 19
#          Function evaluations: 20
#          Gradient evaluations: 20
# Optimization terminated successfully.
#          Current function value: 0.436312
#          Iterations: 16
#          Function evaluations: 18
#          Gradient evaluations: 18
# Optimization terminated successfully.
#          Current function value: 1.961438
#          Iterations: 18
#          Function evaluations: 20
#          Gradient evaluations: 20
# Optimization terminated successfully.
#          Current function value: 1.800267
#          Iterations: 17
#          Function evaluations: 18
#          Gradient evaluations: 18
# Optimization terminated successfully.
#          Current function value: 1.052237
#          Iterations: 17
#          Function evaluations: 18
#          Gradient evaluations: 18
# Optimization terminated successfully.
#          Current function value: 3.642246
#          Iterations: 17
#          Function evaluations: 19
#          Gradient evaluations: 19
# Optimization terminated successfully.
#          Current function value: 3.349445
#          Iterations: 14
#          Function evaluations: 15
#          Gradient evaluations: 15
# Optimization terminated successfully.
#          Current function value: 0.829421
#          Iterations: 15
#          Function evaluations: 17
#          Gradient evaluations: 17
# Optimization terminated successfully.
#          Current function value: 3.782896
#          Iterations: 15
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 1.684687
#          Iterations: 15
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 1.882702
#          Iterations: 20
#          Function evaluations: 22
#          Gradient evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.792895
#          Iterations: 13
#          Function evaluations: 15
#          Gradient evaluations: 15
# Optimization terminated successfully.
#          Current function value: 2.633137
#          Iterations: 11
#          Function evaluations: 13
#          Gradient evaluations: 13
# Optimization terminated successfully.
#          Current function value: 0.241696
#          Iterations: 20
#          Function evaluations: 21
#          Gradient evaluations: 21
# Optimization terminated successfully.
#          Current function value: 2.437514
#          Iterations: 16
#          Function evaluations: 18
#          Gradient evaluations: 18
# Optimization terminated successfully.
#          Current function value: 1.022657
#          Iterations: 16
#          Function evaluations: 18
#          Gradient evaluations: 18
# Optimization terminated successfully.
#          Current function value: 3.263145
#          Iterations: 17
#          Function evaluations: 19
#          Gradient evaluations: 19
# Optimization terminated successfully.
#          Current function value: 5.594462
#          Iterations: 20
#          Function evaluations: 21
#          Gradient evaluations: 21
# Optimization terminated successfully.
#          Current function value: 2.645645
#          Iterations: 16
#          Function evaluations: 17
#          Gradient evaluations: 17
# Optimization terminated successfully.
#          Current function value: 3.845459
#          Iterations: 17
#          Function evaluations: 18
#          Gradient evaluations: 18
# Optimization terminated successfully.
#          Current function value: 2.916124
#          Iterations: 15
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 4.396876
#          Iterations: 21
#          Function evaluations: 22
#          Gradient evaluations: 22
# Optimization terminated successfully.
#          Current function value: 2.081167
#          Iterations: 16
#          Function evaluations: 17
#          Gradient evaluations: 17
# Optimization terminated successfully.
#          Current function value: 4.037074
#          Iterations: 18
#          Function evaluations: 19
#          Gradient evaluations: 19
# Optimization terminated successfully.
#          Current function value: 0.293598
#          Iterations: 16
#          Function evaluations: 17
#          Gradient evaluations: 17
# Optimization terminated successfully.
#          Current function value: 0.689264
#          Iterations: 12
#          Function evaluations: 14
#          Gradient evaluations: 14
# Optimization terminated successfully.
#          Current function value: 0.049322
#          Iterations: 18
#          Function evaluations: 20
#          Gradient evaluations: 20
# Optimization terminated successfully.
#          Current function value: 3.559725
#          Iterations: 13
#          Function evaluations: 14
#          Gradient evaluations: 14
# Optimization terminated successfully.
#          Current function value: 1.982335
#          Iterations: 15
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 2.964468
#          Iterations: 18
#          Function evaluations: 20
#          Gradient evaluations: 20
# Optimization terminated successfully.
#          Current function value: 3.120337
#          Iterations: 17
#          Function evaluations: 18
#          Gradient evaluations: 18
# Optimization terminated successfully.
#          Current function value: 4.458588
#          Iterations: 16
#          Function evaluations: 18
#          Gradient evaluations: 18
# Optimization terminated successfully.
#          Current function value: 2.857227
#          Iterations: 16
#          Function evaluations: 17
#          Gradient evaluations: 17
# Optimization terminated successfully.
#          Current function value: 1.407046
#          Iterations: 17
#          Function evaluations: 19
#          Gradient evaluations: 19
# Optimization terminated successfully.
#          Current function value: 5.614844
#          Iterations: 16
#          Function evaluations: 18
#          Gradient evaluations: 18
# Optimization terminated successfully.
#          Current function value: 4.268211
#          Iterations: 18
#          Function evaluations: 19
#          Gradient evaluations: 19
# Optimization terminated successfully.
#          Current function value: 4.015368
#          Iterations: 16
#          Function evaluations: 17
#          Gradient evaluations: 17
# Optimization terminated successfully.
#          Current function value: 2.163185
#          Iterations: 14
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 2.855489
#          Iterations: 18
#          Function evaluations: 20
#          Gradient evaluations: 20
# Optimization terminated successfully.
#          Current function value: 1.892395
#          Iterations: 15
#          Function evaluations: 17
#          Gradient evaluations: 17
# Optimization terminated successfully.
#          Current function value: 2.094063
#          Iterations: 18
#          Function evaluations: 19
#          Gradient evaluations: 19
# Optimization terminated successfully.
#          Current function value: 0.572118
#          Iterations: 17
#          Function evaluations: 18
#          Gradient evaluations: 18
# Optimization terminated successfully.
#          Current function value: 1.581205
#          Iterations: 20
#          Function evaluations: 21
#          Gradient evaluations: 21
# Optimization terminated successfully.
#          Current function value: 3.429370
#          Iterations: 17
#          Function evaluations: 18
#          Gradient evaluations: 18
# Optimization terminated successfully.
#          Current function value: 0.658823
#          Iterations: 15
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 3.077153
#          Iterations: 20
#          Function evaluations: 21
#          Gradient evaluations: 21
# Optimization terminated successfully.
#          Current function value: 1.290990
#          Iterations: 20
#          Function evaluations: 21
#          Gradient evaluations: 21
# Optimization terminated successfully.
#          Current function value: 2.979929
#          Iterations: 19
#          Function evaluations: 21
#          Gradient evaluations: 21
# Optimization terminated successfully.
#          Current function value: 3.512069
#          Iterations: 17
#          Function evaluations: 18
#          Gradient evaluations: 18
# Optimization terminated successfully.
#          Current function value: 3.139002
#          Iterations: 18
#          Function evaluations: 20
#          Gradient evaluations: 20
# Optimization terminated successfully.
#          Current function value: 1.839263
#          Iterations: 15
#          Function evaluations: 17
#          Gradient evaluations: 17
# Optimization terminated successfully.
#          Current function value: 2.429908
#          Iterations: 20
#          Function evaluations: 21
#          Gradient evaluations: 21
# Optimization terminated successfully.
#          Current function value: 3.090078
#          Iterations: 12
#          Function evaluations: 14
#          Gradient evaluations: 14
# Optimization terminated successfully.
#          Current function value: 3.222690
#          Iterations: 16
#          Function evaluations: 17
#          Gradient evaluations: 17
# Optimization terminated successfully.
#          Current function value: 2.488909
#          Iterations: 14
#          Function evaluations: 15
#          Gradient evaluations: 15
# Optimization terminated successfully.
#          Current function value: 2.172873
#          Iterations: 19
#          Function evaluations: 20
#          Gradient evaluations: 20
# Optimization terminated successfully.
#          Current function value: 2.070243
#          Iterations: 17
#          Function evaluations: 18
#          Gradient evaluations: 18
# Optimization terminated successfully.
#          Current function value: 2.465492
#          Iterations: 17
#          Function evaluations: 19
#          Gradient evaluations: 19
# Optimization terminated successfully.
#          Current function value: 4.543245
#          Iterations: 15
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 2.134302
#          Iterations: 17
#          Function evaluations: 18
#          Gradient evaluations: 18
# Optimization terminated successfully.
#          Current function value: 3.074608
#          Iterations: 17
#          Function evaluations: 18
#          Gradient evaluations: 18
# Optimization terminated successfully.
#          Current function value: 1.654388
#          Iterations: 16
#          Function evaluations: 18
#          Gradient evaluations: 18
# Optimization terminated successfully.
#          Current function value: 2.917687
#          Iterations: 15
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 2.819539
#          Iterations: 14
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 2.410669
#          Iterations: 13
#          Function evaluations: 15
#          Gradient evaluations: 15
# Optimization terminated successfully.
#          Current function value: 2.305609
#          Iterations: 17
#          Function evaluations: 19
#          Gradient evaluations: 19
# Optimization terminated successfully.
#          Current function value: 0.907813
#          Iterations: 14
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 4.350378
#          Iterations: 17
#          Function evaluations: 19
#          Gradient evaluations: 19
# Optimization terminated successfully.
#          Current function value: 0.587441
#          Iterations: 17
#          Function evaluations: 18
#          Gradient evaluations: 18
# Optimization terminated successfully.
#          Current function value: 1.686378
#          Iterations: 15
#          Function evaluations: 17
#          Gradient evaluations: 17
# Optimization terminated successfully.
#          Current function value: 1.900329
#          Iterations: 16
#          Function evaluations: 18
#          Gradient evaluations: 18
# Optimization terminated successfully.
#          Current function value: 3.079096
#          Iterations: 15
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 1.787672
#          Iterations: 15
#          Function evaluations: 17
#          Gradient evaluations: 17
# Optimization terminated successfully.
#          Current function value: 0.183183
#          Iterations: 20
#          Function evaluations: 22
#          Gradient evaluations: 22
# Optimization terminated successfully.
#          Current function value: 2.155698
#          Iterations: 16
#          Function evaluations: 17
#          Gradient evaluations: 17
# Optimization terminated successfully.
#          Current function value: 3.919010
#          Iterations: 15
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 2.955802
#          Iterations: 16
#          Function evaluations: 17
#          Gradient evaluations: 17
# Optimization terminated successfully.
#          Current function value: 2.630389
#          Iterations: 17
#          Function evaluations: 18
#          Gradient evaluations: 18
# Optimization terminated successfully.
#          Current function value: 1.486063
#          Iterations: 17
#          Function evaluations: 18
#          Gradient evaluations: 18
# Optimization terminated successfully.
#          Current function value: 2.226152
#          Iterations: 19
#          Function evaluations: 20
#          Gradient evaluations: 20
# Optimization terminated successfully.
#          Current function value: 2.833859
#          Iterations: 18
#          Function evaluations: 20
#          Gradient evaluations: 20
# Optimization terminated successfully.
#          Current function value: 2.436389
#          Iterations: 18
#          Function evaluations: 20
#          Gradient evaluations: 20
# Optimization terminated successfully.
#          Current function value: 2.363668
#          Iterations: 15
#          Function evaluations: 17
#          Gradient evaluations: 17
# Optimization terminated successfully.
#          Current function value: 2.154828
#          Iterations: 18
#          Function evaluations: 20
#          Gradient evaluations: 20
# Optimization terminated successfully.
#          Current function value: 3.491357
#          Iterations: 18
#          Function evaluations: 20
#          Gradient evaluations: 20
# Optimization terminated successfully.
#          Current function value: 3.028003
#          Iterations: 16
#          Function evaluations: 17
#          Gradient evaluations: 17
# Optimization terminated successfully.
#          Current function value: 2.068148
#          Iterations: 18
#          Function evaluations: 21
#          Gradient evaluations: 21
# Optimization terminated successfully.
#          Current function value: 1.648963
#          Iterations: 20
#          Function evaluations: 22
#          Gradient evaluations: 22
# Optimization terminated successfully.
#          Current function value: 1.701986
# ...
# Optimization terminated successfully.
#          Current function value: 2.754535
#          Iterations: 21
#          Function evaluations: 22
#          Gradient evaluations: 22
# Optimization terminated successfully.
#          Current function value: 3.082703
#          Iterations: 16
#          Function evaluations: 17
#          Gradient evaluations: 17
# Optimization terminated successfully.
#          Current function value: 3.308209
#          Iterations: 19
#          Function evaluations: 21
#          Gradient evaluations: 21
# Optimization terminated successfully.
#          Current function value: 1.781594
#          Iterations: 17
#          Function evaluations: 18
#          Gradient evaluations: 18
# Optimization terminated successfully.
#          Current function value: 3.006646
#          Iterations: 20
#          Function evaluations: 22
#          Gradient evaluations: 22
# Optimization terminated successfully.
#          Current function value: 3.093580
#          Iterations: 21
#          Function evaluations: 24
#          Gradient evaluations: 24
# Optimization terminated successfully.
#          Current function value: 1.603746
#          Iterations: 22
#          Function evaluations: 23
#          Gradient evaluations: 23
# Optimization terminated successfully.
#          Current function value: 2.267371
#          Iterations: 21
#          Function evaluations: 23
#          Gradient evaluations: 23
# Optimization terminated successfully.
#          Current function value: 3.182650
#          Iterations: 20
#          Function evaluations: 22
#          Gradient evaluations: 22
# Optimization terminated successfully.
#          Current function value: 1.576360
#          Iterations: 20
#          Function evaluations: 21
#          Gradient evaluations: 21
# Optimization terminated successfully.
#          Current function value: 1.796951
#          Iterations: 18
#          Function evaluations: 19
#          Gradient evaluations: 19
# Optimization terminated successfully.
#          Current function value: 0.631358
#          Iterations: 19
#          Function evaluations: 21
#          Gradient evaluations: 21
# Optimization terminated successfully.
#          Current function value: 2.007095
#          Iterations: 19
#          Function evaluations: 20
#          Gradient evaluations: 20
# Optimization terminated successfully.
#          Current function value: 1.417117
#          Iterations: 20
#          Function evaluations: 22
#          Gradient evaluations: 22
# Optimization terminated successfully.
#          Current function value: 1.831269
#          Iterations: 19
#          Function evaluations: 21
#          Gradient evaluations: 21
# Optimization terminated successfully.
#          Current function value: 4.101151
#          Iterations: 16
#          Function evaluations: 18
#          Gradient evaluations: 18
# Optimization terminated successfully.
#          Current function value: 2.493352
#          Iterations: 20
#          Function evaluations: 22
#          Gradient evaluations: 22
# Optimization terminated successfully.
#          Current function value: 3.065117
#          Iterations: 21
#          Function evaluations: 22
#          Gradient evaluations: 22
# Optimization terminated successfully.
#          Current function value: 3.197064
#          Iterations: 24
#          Function evaluations: 26
#          Gradient evaluations: 26
# Optimization terminated successfully.
#          Current function value: 1.770371
#          Iterations: 14
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 2.054516
#          Iterations: 18
#          Function evaluations: 19
#          Gradient evaluations: 19
# Optimization terminated successfully.
#          Current function value: 1.981677
#          Iterations: 18
#          Function evaluations: 19
#          Gradient evaluations: 19
# Optimization terminated successfully.
#          Current function value: 3.346581
#          Iterations: 19
#          Function evaluations: 21
#          Gradient evaluations: 21
# Optimization terminated successfully.
#          Current function value: 1.986899
#          Iterations: 20
#          Function evaluations: 22
#          Gradient evaluations: 22
# Optimization terminated successfully.
#          Current function value: 1.798655
#          Iterations: 19
#          Function evaluations: 20
#          Gradient evaluations: 20
# Optimization terminated successfully.
#          Current function value: 2.976048
#          Iterations: 21
#          Function evaluations: 23
#          Gradient evaluations: 23
# Optimization terminated successfully.
#          Current function value: 3.771056
#          Iterations: 23
#          Function evaluations: 24
#          Gradient evaluations: 24
# Optimization terminated successfully.
#          Current function value: 1.612587
#          Iterations: 17
#          Function evaluations: 19
#          Gradient evaluations: 19
# Optimization terminated successfully.
#          Current function value: 3.049626
#          Iterations: 19
#          Function evaluations: 20
#          Gradient evaluations: 20
# Optimization terminated successfully.
#          Current function value: 2.641301
#          Iterations: 20
#          Function evaluations: 22
#          Gradient evaluations: 22
# Optimization terminated successfully.
#          Current function value: 1.875737
#          Iterations: 20
#          Function evaluations: 21
#          Gradient evaluations: 21
# Optimization terminated successfully.
#          Current function value: 2.812381
#          Iterations: 17
#          Function evaluations: 19
#          Gradient evaluations: 19
# Optimization terminated successfully.
#          Current function value: 2.235733
#          Iterations: 17
#          Function evaluations: 18
#          Gradient evaluations: 18
# Optimization terminated successfully.
#          Current function value: 1.889514
#          Iterations: 20
#          Function evaluations: 22
#          Gradient evaluations: 22
# Optimization terminated successfully.
#          Current function value: 2.820448
#          Iterations: 17
#          Function evaluations: 18
#          Gradient evaluations: 18
# Optimization terminated successfully.
#          Current function value: 2.414893
#          Iterations: 21
#          Function evaluations: 22
#          Gradient evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.834544
#          Iterations: 20
#          Function evaluations: 21
#          Gradient evaluations: 21
# Optimization terminated successfully.
#          Current function value: 3.207803
#          Iterations: 19
#          Function evaluations: 21
#          Gradient evaluations: 21
# Optimization terminated successfully.
#          Current function value: 1.333668
#          Iterations: 18
#          Function evaluations: 20
#          Gradient evaluations: 20
# Optimization terminated successfully.
#          Current function value: 1.868326
#          Iterations: 19
#          Function evaluations: 21
#          Gradient evaluations: 21
# Optimization terminated successfully.
#          Current function value: 1.985394
#          Iterations: 20
#          Function evaluations: 21
#          Gradient evaluations: 21
# Optimization terminated successfully.
#          Current function value: 2.508886
#          Iterations: 19
#          Function evaluations: 21
#          Gradient evaluations: 21
# Optimization terminated successfully.
#          Current function value: 3.307648
#          Iterations: 18
#          Function evaluations: 19
#          Gradient evaluations: 19
# Optimization terminated successfully.
#          Current function value: 3.220390
#          Iterations: 23
#          Function evaluations: 25
#          Gradient evaluations: 25
# Optimization terminated successfully.
#          Current function value: 2.971993
#          Iterations: 20
#          Function evaluations: 22
#          Gradient evaluations: 22
# Optimization terminated successfully.
#          Current function value: 1.930336
#          Iterations: 22
#          Function evaluations: 24
#          Gradient evaluations: 24
# Optimization terminated successfully.
#          Current function value: 2.815824
#          Iterations: 20
#          Function evaluations: 22
#          Gradient evaluations: 22
# Optimization terminated successfully.
#          Current function value: 2.768112
#          Iterations: 21
#          Function evaluations: 22
#          Gradient evaluations: 22
# Optimization terminated successfully.
#          Current function value: 3.670537
#          Iterations: 20
#          Function evaluations: 22
#          Gradient evaluations: 22
# Optimization terminated successfully.
#          Current function value: 2.532841
#          Iterations: 25
#          Function evaluations: 26
#          Gradient evaluations: 26
# Optimization terminated successfully.
#          Current function value: 1.924341
#          Iterations: 20
#          Function evaluations: 22
#          Gradient evaluations: 22
# Optimization terminated successfully.
#          Current function value: 3.068585
#          Iterations: 21
#          Function evaluations: 22
#          Gradient evaluations: 22
# Optimization terminated successfully.
#          Current function value: 2.075602
#          Iterations: 22
#          Function evaluations: 23
#          Gradient evaluations: 23
# Optimization terminated successfully.
#          Current function value: 3.391450
#          Iterations: 20
#          Function evaluations: 22
#          Gradient evaluations: 22
# Optimization terminated successfully.
#          Current function value: 2.589027
#          Iterations: 18
#          Function evaluations: 19
#          Gradient evaluations: 19
# Optimization terminated successfully.
#          Current function value: 3.071227
#          Iterations: 24
#          Function evaluations: 26
#          Gradient evaluations: 26
# Optimization terminated successfully.
#          Current function value: 1.981083
#          Iterations: 17
#          Function evaluations: 18
#          Gradient evaluations: 18
# Optimization terminated successfully.
#          Current function value: 1.794893
#          Iterations: 17
#          Function evaluations: 19
#          Gradient evaluations: 19
# Optimization terminated successfully.
#          Current function value: 2.382768
#          Iterations: 19
#          Function evaluations: 21
#          Gradient evaluations: 21
# Optimization terminated successfully.
#          Current function value: 1.811282
#          Iterations: 20
#          Function evaluations: 21
#          Gradient evaluations: 21
# Optimization terminated successfully.
#          Current function value: 2.377048
#          Iterations: 18
#          Function evaluations: 20
#          Gradient evaluations: 20
# Optimization terminated successfully.
#          Current function value: 1.822056
#          Iterations: 19
#          Function evaluations: 21
#          Gradient evaluations: 21
# Optimization terminated successfully.
#          Current function value: 3.048226
#          Iterations: 21
#          Function evaluations: 23
#          Gradient evaluations: 23
# Optimization terminated successfully.
#          Current function value: 3.827751
#          Iterations: 20
#          Function evaluations: 22
#          Gradient evaluations: 22
# Optimization terminated successfully.
#          Current function value: 3.638372
#          Iterations: 17
#          Function evaluations: 19
#          Gradient evaluations: 19
# Optimization terminated successfully.
#          Current function value: 3.351003
#          Iterations: 19
#          Function evaluations: 20
#          Gradient evaluations: 20
# Optimization terminated successfully.
#          Current function value: 2.049106
#          Iterations: 18
#          Function evaluations: 20
#          Gradient evaluations: 20
# Optimization terminated successfully.
#          Current function value: 1.910045
#          Iterations: 16
#          Function evaluations: 17
#          Gradient evaluations: 17
# Optimization terminated successfully.
#          Current function value: 2.545690
#          Iterations: 16
#          Function evaluations: 17
#          Gradient evaluations: 17
# Optimization terminated successfully.
#          Current function value: 3.457665
#          Iterations: 20
#          Function evaluations: 21
#          Gradient evaluations: 21
# Optimization terminated successfully.
#          Current function value: 3.705722
#          Iterations: 20
#          Function evaluations: 21
#          Gradient evaluations: 21
# Optimization terminated successfully.
#          Current function value: 1.653444
#          Iterations: 20
#          Function evaluations: 22
#          Gradient evaluations: 22
# Optimization terminated successfully.
#          Current function value: 1.558502
#          Iterations: 22
#          Function evaluations: 23
#          Gradient evaluations: 23
# Optimization terminated successfully.
#          Current function value: 2.918769
#          Iterations: 22
#          Function evaluations: 23
#          Gradient evaluations: 23
# Optimization terminated successfully.
#          Current function value: 2.000248
#          Iterations: 19
#          Function evaluations: 21
#          Gradient evaluations: 21
# Optimization terminated successfully.
#          Current function value: 3.077778
#          Iterations: 20
#          Function evaluations: 21
#          Gradient evaluations: 21
# Optimization terminated successfully.
#          Current function value: 3.221577
#          Iterations: 21
#          Function evaluations: 23
#          Gradient evaluations: 23
# Optimization terminated successfully.
#          Current function value: 2.121752
#          Iterations: 20
#          Function evaluations: 21
#          Gradient evaluations: 21
# Optimization terminated successfully.
#          Current function value: 2.865447
#          Iterations: 17
#          Function evaluations: 18
#          Gradient evaluations: 18
# Optimization terminated successfully.
#          Current function value: 2.484681
#          Iterations: 24
#          Function evaluations: 25
#          Gradient evaluations: 25
# Optimization terminated successfully.
#          Current function value: 2.193544
#          Iterations: 19
#          Function evaluations: 20
#          Gradient evaluations: 20
# Optimization terminated successfully.
#          Current function value: 3.206814
#          Iterations: 20
#          Function evaluations: 22
#          Gradient evaluations: 22
# Optimization terminated successfully.
#          Current function value: 1.901330
#          Iterations: 19
#          Function evaluations: 21
#          Gradient evaluations: 21
# Optimization terminated successfully.
#          Current function value: 2.438880
#          Iterations: 18
#          Function evaluations: 20
#          Gradient evaluations: 20
# Optimization terminated successfully.
#          Current function value: 2.059065
#          Iterations: 19
#          Function evaluations: 21
#          Gradient evaluations: 21
# Optimization terminated successfully.
#          Current function value: 2.138267
#          Iterations: 18
#          Function evaluations: 20
#          Gradient evaluations: 20
# Optimization terminated successfully.
#          Current function value: 1.865980
#          Iterations: 22
#          Function evaluations: 23
#          Gradient evaluations: 23
# Optimization terminated successfully.
#          Current function value: 1.582347
#          Iterations: 18
#          Function evaluations: 19
#          Gradient evaluations: 19
# Optimization terminated successfully.
#          Current function value: 1.804158
#          Iterations: 17
#          Function evaluations: 18
#          Gradient evaluations: 18
# Optimization terminated successfully.
#          Current function value: 3.134579
#          Iterations: 18
#          Function evaluations: 19
#          Gradient evaluations: 19
# Optimization terminated successfully.
#          Current function value: 3.133520
#          Iterations: 24
#          Function evaluations: 26
#          Gradient evaluations: 26
# Optimization terminated successfully.
#          Current function value: 1.885970
#          Iterations: 17
#          Function evaluations: 18
#          Gradient evaluations: 18
# Optimization terminated successfully.
#          Current function value: 1.721745
#          Iterations: 19
#          Function evaluations: 21
#          Gradient evaluations: 21

# %% [markdown]
# ## Comparing the learned parameters of ridge regression and lasso regression
# With different regularization methods, the learned parameters behaves differently. In this section you are going to compare the parameters learned from the ridge regression and the lasso regression. Remember that the loss and subgradient of the lasso regression has the form:
# $$\begin{eqnarray*}
# J(\theta) & = & \frac{1}{2m} \left( \sum_{i=1}^{m} {( y^{(i)} - h_\theta(x^{(i)})}^2\right) + \frac{\lambda}{m} \sum_{j=1}^{n} |{\theta_j}|\\
# \frac{\partial J(\theta)}{\partial \theta_0} & = & \frac{1}{m} \sum_{i=1}^{m} (h_\theta(x^{(i)}) - y^{(i)}){x_j}^{(i)} \\
# \frac{\partial J(\theta)}{\partial \theta_j} & = & \left(\frac{1}{m} \sum_{i=1}^{m} (h_\theta(x^{(i)}) - y^{(i)} ){x_j}^{(i)}\right) + \frac{\lambda}{m}{\mbox{sign}(\theta_j)} \; \; \; \mbox{ for }j \geq 1\\
# \end{eqnarray*}$$First complete the **loss** and **grad_loss** function in the **LassoReg_SquaredLoss** class in **reg_linear_regressor_multi.py**, then train the parameters using **XX_poly**. Use $\lambda = 0.5$. Plot the magnitude of entries of $\theta$ trained from each method in descending order, and report what you see in **writeup.pdf**.

# %%
from reg_linear_regressor_multi import LassoLinearReg_SquaredLoss
reg = 0.5

# Create the two regressors.

ridge_regressor = RegularizedLinearReg_SquaredLoss()
lasso_regressor = LassoLinearReg_SquaredLoss()

# Train them with the polynomial expansion.

ridge_theta = np.abs(ridge_regressor.train(XX_poly,y,reg=reg,num_iters=10000))[1:]
lasso_theta = np.abs(lasso_regressor.train(XX_poly,y,reg=reg,num_iters=10000))[1:]

# Sort the absolute values of the parameters.

sorted_ridge_theta = -np.sort(-ridge_theta)
sorted_lasso_theta = -np.sort(-lasso_theta)

# Plot the parameters.

num_params = len(ridge_theta)
plt.plot(range(num_params), sorted_ridge_theta, label='ridge params')
plt.plot(range(num_params), sorted_lasso_theta, label='lasso params')
plt.legend()
plt.show()

# %% [markdown]
# ## Extra Credit: Building regularized models for Boston data set (10 points)
# -- completely optional
#
# Perform a bias variance analysis of the Boston housing data set with the thirteen predictors, following the steps on the simple data set above. Use sklearn's  built-in functions to split the data into training, validation and test sets. What is the lowest achievable error on the test set with $\lambda = 0$? Select the best value for $\lambda$ and report the test set error with the best $\lambda$. Use the technique of adding features to extend each column of the Boston data set with powers of the values in the column. Repeat the bias-variance analysis with quadratic and cubic features. What is the test set error with quadratic features with the best $\lambda$ chosen with the validation set? What is the test set error with cubic features with the best $\lambda$ chosen with the validation set? Put your analysis code in a separate Python script or notebook called bostonexpt.py or bostonexpt.ipynb. Present your results analytically with plots to support your findings. Discuss the impact of regularization for building good models for the Boston housing data set.

# %%
### TODO: your Boston code here or in a separate notebook.
